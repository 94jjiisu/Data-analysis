# %%
# !pip install --upgrade pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading https://files.pythonhosted.org/packages/14/52/accb990baebe0063977f26e02df36aa7eb4015ed4e86f828cd76273cd6f1/pandas_datareader-0.8.1-py2.py3-none-any.whl (107kB)
# Requirement already satisfied, skipping upgrade: requests>=2.3.0 in c:\anaconda3\lib\site-packages (from pandas-datareader) (2.19.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in c:\anaconda3\lib\site-packages (from pandas-datareader) (0.23.4)
# Requirement already satisfied, skipping upgrade: lxml in c:\anaconda3\lib\site-packages (from pandas-datareader) (4.2.4)
# Requirement already satisfied, skipping upgrade: idna<2.8,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.3.0->pandas-datareader) (2.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.3.0->pandas-datareader) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3<1.24,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.3.0->pandas-datareader) (1.23)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests>=2.3.0->pandas-datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in c:\anaconda3\lib\site-packages (from pandas>=0.21->pandas-datareader) (2.7.3)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in c:\anaconda3\lib\site-packages (from pandas>=0.21->pandas-datareader) (2018.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in c:\anaconda3\lib\site-packages (from pandas>=0.21->pandas-datareader) (1.14.5)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas>=0.21->pandas-datareader) (1.11.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.8.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
s = pd.Series([1,2,3,4], name='daily returns')
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: daily returns, dtype: int64

# %%
s * 100
# Out:
# 0     81.025631
# 1     75.256725
# 2   -178.172987
# 3     58.684763
# Name: daily returns, dtype: float64

# %%
np.abs(s)
# Out:
# 0    0.810256
# 1    0.752567
# 2    1.781730
# 3    0.586848
# Name: daily returns, dtype: float64

# %%
s.describe()
# Out:
# count    4.000000
# mean     0.091985
# std      1.252728
# min     -1.781730
# 25%     -0.005297
# 50%      0.669707
# 75%      0.766990
# max      0.810256
# Name: daily returns, dtype: float64

# %%
s.index = ['AMZN', 'AAPL', 'MSFT', 'GOOG']

# %%
s
# Out:
# AMZN    0.810256
# AAPL    0.752567
# MSFT   -1.781730
# GOOG    0.586848
# Name: daily returns, dtype: float64

# %%
s['AMZN']
# Out:
# 0.8102563073555797

# %%
s['AMZN']=0
s
# Out:
# AMZN    0.000000
# AAPL    0.752567
# MSFT   -1.781730
# GOOG    0.586848
# Name: daily returns, dtype: float64

# %%
'AAPL' in s
# Out:
# True

# %%
df = pd.read_csv('C:/Users/hufs/test.csv')

# %%
df
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
df[2:5]
# Out:
#   country country isocode  year          POP       XRAT         tcgdp  \
# 2   India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3  Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4  Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
#
#           cc         cg
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954

# %%
df[['country', 'year']]
# Out:
#          country  year
# 0      Argentina  2000
# 1      Australia  2000
# 2          India  2000
# 3         Israel  2000
# 4         Malawi  2000
# 5   South Africa  2000
# 6  United States  2000
# 7        Uruguay  2000

# %%
df.iloc[2:5, 0:3]
# Out:
#   country country isocode  year
# 2   India             IND  2000
# 3  Israel             ISR  2000
# 4  Malawi             MWI  2000

# %%
df.loc[df.index[2:5], ['country', 'tcgdp']]
# Out:
#   country         tcgdp
# 2   India  1.728144e+06
# 3  Israel  1.292539e+05
# 4  Malawi  5.026222e+03

# %%
df = df[['country', 'POP', 'tcgdp']]

# %%
df
# Out:
#          country          POP         tcgdp
# 0      Argentina    37335.653  2.950722e+05
# 1      Australia    19053.186  5.418047e+05
# 2          India  1006300.297  1.728144e+06
# 3         Israel     6114.570  1.292539e+05
# 4         Malawi    11801.505  5.026222e+03
# 5   South Africa    45064.098  2.272424e+05
# 6  United States   282171.957  9.898700e+06
# 7        Uruguay     3219.793  2.525596e+04

# %%
df = df.set_index('country')
df
# Out:
#                        POP         tcgdp
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
df.columns = 'population', 'total GDP'
df
# Out:
#                 population     total GDP
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
df
# Out:
#                  population     total GDP   populoation
# country
# Argentina      3.733565e+07  2.950722e+05  3.733565e+07
# Australia      1.905319e+07  5.418047e+05  1.905319e+07
# India          1.006300e+09  1.728144e+06  1.006300e+09
# Israel         6.114570e+06  1.292539e+05  6.114570e+06
# Malawi         1.180150e+07  5.026222e+03  1.180150e+07
# South Africa   4.506410e+07  2.272424e+05  4.506410e+07
# United States  2.821720e+08  9.898700e+06  2.821720e+08
# Uruguay        3.219793e+06  2.525596e+04  3.219793e+06

# %%
df['GDP percap'] = df['total GDP'] * 1e6 / df['population']
df
# Out:
#                  population     total GDP   populoation    GDP percap
# country
# Argentina      3.733565e+07  2.950722e+05  3.733565e+07   7903.229085
# Australia      1.905319e+07  5.418047e+05  1.905319e+07  28436.433261
# India          1.006300e+09  1.728144e+06  1.006300e+09   1717.324719
# Israel         6.114570e+06  1.292539e+05  6.114570e+06  21138.672749
# Malawi         1.180150e+07  5.026222e+03  1.180150e+07    425.896679
# South Africa   4.506410e+07  2.272424e+05  4.506410e+07   5042.647686
# United States  2.821720e+08  9.898700e+06  2.821720e+08  35080.381854
# Uruguay        3.219793e+06  2.525596e+04  3.219793e+06   7843.970620

# %%
del df['populoation']

# %%
df
# Out:
#                  population     total GDP    GDP percap
# country
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Australia      1.905319e+07  5.418047e+05  28436.433261
# India          1.006300e+09  1.728144e+06   1717.324719
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Malawi         1.180150e+07  5.026222e+03    425.896679
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# United States  2.821720e+08  9.898700e+06  35080.381854
# Uruguay        3.219793e+06  2.525596e+04   7843.970620

# %%
df['GDP percap'].plot(kind='bar')
plt.show()

# %%
df = df.sort_values(by='GDP percap', ascending=False)
df
# Out:
#                  population     total GDP    GDP percap
# country
# United States  2.821720e+08  9.898700e+06  35080.381854
# Australia      1.905319e+07  5.418047e+05  28436.433261
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Uruguay        3.219793e+06  2.525596e+04   7843.970620
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# India          1.006300e+09  1.728144e+06   1717.324719
# Malawi         1.180150e+07  5.026222e+03    425.896679

# %%
df['GDP percap'].plot(kind='bar')
plt.show()

# %%
Udata = pd.read_csv('C:/Users/hufs/raw_data_file2_SKY.csv')

# %%
Udata
# Out:
#     Total ranking  Economics  Business  Arts and Humanitties  \
# 0               1        1.0       1.0                   1.0
# 1               2        4.0       4.0                   2.0
# 2               3        2.0       2.0                   3.0
# 3               4        6.0       7.0                   8.0
# 4               5        3.0       3.0                   4.0
# 5               6        5.0       5.0                   5.0
# 6               7        9.0       8.0                   9.0
# 7               8        8.0       9.0                   NaN
# 8               9        7.0       6.0                   7.0
# 9              10       10.0       NaN                   6.0
# 10             11        NaN      11.0                   NaN
#
#     Modern linguistics  English Literatrue  Finance & Accounting  Sociology
# 0                  1.0                 2.0                   1.0        1.0
# 1                  6.0                 3.0                   4.0        2.0
# 2                  2.0                 1.0                   2.0        3.0
# 3                 10.0                 5.0                   6.0        NaN
# 4                  5.0                 6.0                   3.0        4.0
# 5                  4.0                 8.0                   5.0        5.0
# 6                  7.0                 7.0                   NaN        6.0
# 7                  NaN                 NaN                   NaN        NaN
# 8                  8.0                 NaN                   7.0        7.0
# 9                  3.0                 4.0                   NaN        NaN
# 10                11.0                 NaN                   NaN        NaN

# %%
Udata.corr('spearman')
# Out:
#                       Total ranking  Economics  Business  \
# Total ranking              1.000000   0.866667  0.818182
# Economics                  0.866667   1.000000  0.966667
# Business                   0.818182   0.966667  1.000000
# Arts and Humanitties       0.733333   0.833333  0.928571
# Modern linguistics         0.503030   0.533333  0.900000
# English Literatrue         0.666667   0.547619  0.714286
# Finance & Accounting       0.750000   1.000000  0.964286
# Sociology                  1.000000   0.857143  0.857143
#
#                       Arts and Humanitties  Modern linguistics  \
# Total ranking                     0.733333            0.503030
# Economics                         0.833333            0.533333
# Business                          0.928571            0.900000
# Arts and Humanitties              1.000000            0.716667
# Modern linguistics                0.716667            1.000000
# English Literatrue                0.666667            0.547619
# Finance & Accounting              0.857143            0.857143
# Sociology                         0.964286            0.750000
#
#                       English Literatrue  Finance & Accounting  Sociology
# Total ranking                   0.666667              0.750000   1.000000
# Economics                       0.547619              1.000000   0.857143
# Business                        0.714286              0.964286   0.857143
# Arts and Humanitties            0.666667              0.857143   0.964286
# Modern linguistics              0.547619              0.857143   0.750000
# English Literatrue              1.000000              0.657143   0.771429
# Finance & Accounting            0.657143              1.000000   0.828571
# Sociology                       0.771429              0.828571   1.000000

# %%
Udata1 = Udata.corr('spearman')

# %%
Udata1
# Out:
#                       Total ranking  Economics  Business  \
# Total ranking              1.000000   0.866667  0.818182
# Economics                  0.866667   1.000000  0.966667
# Business                   0.818182   0.966667  1.000000
# Arts and Humanitties       0.733333   0.833333  0.928571
# Modern linguistics         0.503030   0.533333  0.900000
# English Literatrue         0.666667   0.547619  0.714286
# Finance & Accounting       0.750000   1.000000  0.964286
# Sociology                  1.000000   0.857143  0.857143
#
#                       Arts and Humanitties  Modern linguistics  \
# Total ranking                     0.733333            0.503030
# Economics                         0.833333            0.533333
# Business                          0.928571            0.900000
# Arts and Humanitties              1.000000            0.716667
# Modern linguistics                0.716667            1.000000
# English Literatrue                0.666667            0.547619
# Finance & Accounting              0.857143            0.857143
# Sociology                         0.964286            0.750000
#
#                       English Literatrue  Finance & Accounting  Sociology
# Total ranking                   0.666667              0.750000   1.000000
# Economics                       0.547619              1.000000   0.857143
# Business                        0.714286              0.964286   0.857143
# Arts and Humanitties            0.666667              0.857143   0.964286
# Modern linguistics              0.547619              0.857143   0.750000
# English Literatrue              1.000000              0.657143   0.771429
# Finance & Accounting            0.657143              1.000000   0.828571
# Sociology                       0.771429              0.828571   1.000000

# %%
Udata1 = Udata1.sort_values(by='Total ranking', ascending=False)
Udata1
# Out:
#                       Total ranking  Economics  Business  \
# Total ranking              1.000000   0.866667  0.818182
# Sociology                  1.000000   0.857143  0.857143
# Economics                  0.866667   1.000000  0.966667
# Business                   0.818182   0.966667  1.000000
# Finance & Accounting       0.750000   1.000000  0.964286
# Arts and Humanitties       0.733333   0.833333  0.928571
# English Literatrue         0.666667   0.547619  0.714286
# Modern linguistics         0.503030   0.533333  0.900000
#
#                       Arts and Humanitties  Modern linguistics  \
# Total ranking                     0.733333            0.503030
# Sociology                         0.964286            0.750000
# Economics                         0.833333            0.533333
# Business                          0.928571            0.900000
# Finance & Accounting              0.857143            0.857143
# Arts and Humanitties              1.000000            0.716667
# English Literatrue                0.666667            0.547619
# Modern linguistics                0.716667            1.000000
#
#                       English Literatrue  Finance & Accounting  Sociology
# Total ranking                   0.666667              0.750000   1.000000
# Sociology                       0.771429              0.828571   1.000000
# Economics                       0.547619              1.000000   0.857143
# Business                        0.714286              0.964286   0.857143
# Finance & Accounting            0.657143              1.000000   0.828571
# Arts and Humanitties            0.666667              0.857143   0.964286
# English Literatrue              1.000000              0.657143   0.771429
# Modern linguistics              0.547619              0.857143   0.750000

# %%
Udata1.loc[Udata1.index[0:9], ['Total ranking', 'Sociology', 'Economics', 'Business', 'Finance & Accounting', 'Arts and Humanitties', 'English Literatrue', 'Modern linguistics']]
# Out:
#                       Total ranking  Sociology  Economics  Business  \
# Total ranking              1.000000   1.000000   0.866667  0.818182
# Sociology                  1.000000   1.000000   0.857143  0.857143
# Economics                  0.866667   0.857143   1.000000  0.966667
# Business                   0.818182   0.857143   0.966667  1.000000
# Finance & Accounting       0.750000   0.828571   1.000000  0.964286
# Arts and Humanitties       0.733333   0.964286   0.833333  0.928571
# English Literatrue         0.666667   0.771429   0.547619  0.714286
# Modern linguistics         0.503030   0.750000   0.533333  0.900000
#
#                       Finance & Accounting  Arts and Humanitties  \
# Total ranking                     0.750000              0.733333
# Sociology                         0.828571              0.964286
# Economics                         1.000000              0.833333
# Business                          0.964286              0.928571
# Finance & Accounting              1.000000              0.857143
# Arts and Humanitties              0.857143              1.000000
# English Literatrue                0.657143              0.666667
# Modern linguistics                0.857143              0.716667
#
#                       English Literatrue  Modern linguistics
# Total ranking                   0.666667            0.503030
# Sociology                       0.771429            0.750000
# Economics                       0.547619            0.533333
# Business                        0.714286            0.900000
# Finance & Accounting            0.657143            0.857143
# Arts and Humanitties            0.666667            0.716667
# English Literatrue              1.000000            0.547619
# Modern linguistics              0.547619            1.000000

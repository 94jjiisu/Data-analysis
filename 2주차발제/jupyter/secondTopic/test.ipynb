# %%
import csv
year = []
total = []
f = open('csv/milk.csv', 'r', encoding='utf-8')
csvReader = csv.reader(f)

for row in csvReader:
    year.append(row[0])
    total.append(row[1])

f.close()

# %%
year
# Out:
# ['\ufeffyear',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009']

# %%
total
# Out:
# ['total',
#  '410,629',
#  '482,880',
#  '562,447',
#  '675,168',
#  '784,324',
#  '931,384',
#  '1,120,076',
#  '1,348,497',
#  '1,581,769',
#  '1,559,405',
#  '1,751,153',
#  '1,827,069',
#  '1,928,708',
#  '1,948,951',
#  '2,142,000',
#  '2,207,014',
#  '2,268,059',
#  '2,449,854',
#  '1,957,746',
#  '1,894,788',
#  '2,280,881',
#  '2,348,242',
#  '2,300,612',
#  '2,465,674',
#  '2,382,735',
#  '2,248,965',
#  '2,258,397',
#  '2,254,010',
#  '2,228,247',
#  '2,211,004']

# %%
import matplotlib.pyplot as plt
import numpy
import pandas as pd

# %%
plt.title('Milk Production')
plt.xlabel('year')
plt.ylabel('total')
plt.plot(year,total)
plt.show()

# %%
milk.index=milk.index.astype('int')
milk.plot(ylim=[40000,2400000])

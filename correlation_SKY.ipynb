# %%
import pandsas as pd
data = pd.read_csv('C:/Users/1/raw_data_file2_SKY.csv')
# Out:
#   File "<ipython-input-1-594d0a3888f8>", line 2
#     data = pd.read_csv(C:/Users/1/raw_data_file2_SKY.csv)
#                         ^
# SyntaxError: invalid syntax

# %%
import pandsas as pd
data = pd.read_csv('C:/Users/1/raw_data_file2_SKY.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-914ad59c9548> in <module>
# ----> 1 import pandsas as pd
#       2 data = pd.read_csv('C:/Users/1/raw_data_file2_SKY.csv')
#
# ModuleNotFoundError: No module named 'pandsas'

# %%
import pandas as pd
data = pd.read_csv('C:/Users/1/raw_data_file2_SKY.csv')

# %%
data
# Out:
#     Total ranking  Economics  Business  Arts and Humanitties  \
# 0               1        1.0       1.0                   1.0
# 1               2        4.0       4.0                   2.0
# 2               3        2.0       2.0                   3.0
# 3               4        6.0       7.0                   8.0
# 4               5        3.0       3.0                   4.0
# 5               6        5.0       5.0                   5.0
# 6               7        9.0       8.0                   9.0
# 7               8        8.0       9.0                   NaN
# 8               9        7.0       6.0                   7.0
# 9              10       10.0       NaN                   6.0
# 10             11        NaN      11.0                   NaN
#
#     Modern linguistics  English Literatrue  Finance & Accounting  Sociology
# 0                  1.0                 2.0                   1.0        1.0
# 1                  6.0                 3.0                   4.0        2.0
# ...

# %%
corr.pd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a628b11ce16a> in <module>
# ----> 1 corr.pd()
#
# NameError: name 'corr' is not defined

# %%
data.corr()
# Out:
#                       Total ranking  Economics  Business  \
# Total ranking              1.000000   0.866667  0.837662
# Economics                  0.866667   1.000000  0.966667
# Business                   0.837662   0.966667  1.000000
# Arts and Humanitties       0.698054   0.816872  0.935110
# Modern linguistics         0.480483   0.454330  0.900039
# English Literatrue         0.540108   0.490990  0.686892
# Finance & Accounting       0.774278   1.000000  0.964286
# Sociology                  0.994566   0.848122  0.832240
#
#                       Arts and Humanitties  Modern linguistics  \
# Total ranking                     0.698054            0.480483
# Economics                         0.816872            0.454330
# Business                          0.935110            0.900039
# Arts and Humanitties              1.000000            0.715497
# Modern linguistics                0.715497            1.000000
# English Literatrue                0.642082            0.480096
# ...
